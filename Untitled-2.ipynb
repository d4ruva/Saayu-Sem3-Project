# %%
import pandas as pd
import requests

# %%
file = pd.read_csv('mobiles_clean.csv')

# %%
file.head()
# Out:
#    Brand                 Model  Mobile Weight RAM Front Camera Back Camera  \
# 0  Apple       iPhone 16 128GB          174.0   6         12MP        48MP
# 1  Apple       iPhone 16 256GB          174.0   6         12MP        48MP
# 2  Apple       iPhone 16 512GB          174.0   6         12MP        48MP
# 3  Apple  iPhone 16 Plus 128GB          203.0   6         12MP        48MP
# 4  Apple  iPhone 16 Plus 256GB          203.0   6         12MP        48MP
#
#     Processor Battery Capacity Screen Size   Price  Launched Year
# 0  A17 Bionic            3,600         6.1  79,999           2024
# 1  A17 Bionic            3,600         6.1  84,999           2024
# 2  A17 Bionic            3,600         6.1  89,999           2024
# 3  A17 Bionic            4,200         6.7  89,999           2024
# 4  A17 Bionic            4,200         6.7  94,999           2024

# %%
requests.get("http://localhost:8000/api/").text
# Out:
# '[]'

# %%
file.Brand
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 file.get("Brand")
#
# AttributeError: 'str' object has no attribute 'get'
