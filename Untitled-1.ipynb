# %%
import pandas as pd

# %%
pd.read_csv("mobiles_clean.csv")
# Out:
# 0        Apple
# 1        Apple
# 2        Apple
# 3        Apple
# 4        Apple
#         ...
# 925       Poco
# 926       Poco
# 927    Samsung
# 928    Samsung
# 929    Samsung
# Name: Brand, Length: 930, dtype: object
